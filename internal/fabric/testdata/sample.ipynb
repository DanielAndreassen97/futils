# %% [markdown]
# # NB_BronzeToSilver
# Refreshes silver tables from bronze.

# %%
# Parameters — override at job submission time
specific_table_names = "all"      # comma-separated or 'all'
rewrite_table = False              # full reload when True
batch_size = 50000
sample_rate = 1.0
target_lakehouse = 'Silver_LH'

# %%
print('real work happens here')
